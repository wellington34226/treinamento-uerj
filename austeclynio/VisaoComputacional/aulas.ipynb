# %% [markdown]
# # Aula 1
#
# ## Instalação dos programas
#
# - Python 3.12
# - VS Code
#
# ## Instalação das bibliotecas
#
# ### Python
#
# - Numpy
# - Opencv-python
# - Jupter
# - Ipython
#
# ### VS Code
#
# - Python
# - Python Indent
# - Jupter

# %%
# Importação das bibliotecas
import os
import numpy as np
import cv2 as cv

originais = os.path.abspath('fontesImagens')
copias = os.path.abspath('saidaImagens')

# %% [markdown]
# # Aula 2
# ## Instalação
#
# - Pyreadline

# %% [markdown]
# ## Exemplos

# %%
# Exemplo 01

# Load a color image in grayscale
img = cv.imread(os.path.join(originais,'Visao_Computacional_Logo_Imagem.png'),0)
assert img is not None, "Arquivo não encontrado!"
print(f'Logo Monocromático dimensão (y,x): {img.shape}') # y,x
print(f'Logo Monocromático tamanho: {img.size} bytes')
cv.imshow('OpenCV - GrayScale',img)
cv.waitKey(5000)
# Load a color image 
img = cv.imread(os.path.join(originais,'Visao_Computacional_Logo_Imagem.png'),1)
print(f'Logo colorida dimensão (y,x,n): {img.shape}') # y,x,n
print(f'Logo colorida tamanho: {img.size} bytes')
cv.imshow('OpenCV - Color',img)
cv.waitKey(5000)
#Write image
cv.imwrite(os.path.join(copias,"Visao_Computacional_Logo_Imagem.png"), img)
cv.destroyAllWindows()

# %%
# Exercicio 01

# # Load a color image 
img = cv.imread(os.path.join(originais,'dragoes.jpg'),1)
print(f'Logo colorida dimensão (y,x,n): {img.shape}') # y,x,n
print(f'Logo colorida tamanho: {img.size} bytes')
cv.imshow('OpenCV - Color',img)
# Load a color image in grayscale
img = cv.imread(os.path.join(originais,'dragoes.jpg'),0)
assert img is not None, "Arquivo não encontrado!"
print(f'Logo Monocromático dimensão (y,x): {img.shape}') # y,x
print(f'Logo Monocromático tamanho: {img.size} bytes')
cv.imshow('OpenCV - GrayScale',img)
cv.waitKey(5000)
#Write image
cv.imwrite(os.path.join(copias,"dragoes.jpg"), img)
cv.destroyAllWindows()

# %%
# Exemplo 02

# Load a color image
img = cv.imread(os.path.join(originais,'BGR_Azul_Verde_Vermelho.png'),1)

print(f'Dimensão (y,x,n): {img.shape}') # y,x,n

# General Pixel Value (BGR)
# img[y,x]
print(f'Pixel (100,70): {img[100,70]}')
print(f'Pixel (100,210): {img[100,210]}')
print(f'Pixel (100,140): {img[100,140]}')

# By Matrix
# img[y,x,#]
print(f'Pixel (100,70,0): {img[100,70,0]}')
print(f'Pixel (100,70,1): {img[100,70,1]}')
print(f'Pixel (100,70,2): {img[100,70,2]}')


# By Matrix
print(f'Pixel (140,140,0): {img[140,140,0]}')
print(f'Pixel (140,140,1): {img[140,140,1]}')
print(f'Pixel (140,140,2): {img[140,140,2]}')

# By Matrix
print(f'Pixel (50,210,0): {img[50,210,0]}')
print(f'Pixel (50,210,1): {img[50,210,1]}')
print(f'Pixel (50,210,2): {img[50,210,2]}')

cv.imshow('OpenCV - Color',img)
cv.waitKey(5000)

# Modify Pixel Color
for i in range(100):  # y
  for j in range(100): # x
    img[i,j]=[0,0,0]   # altera para cor preta

cv.imshow('OpenCV - Color _ Modified',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exemplo 03

# Load a color image
img = cv.imread(os.path.join(originais,'BGR_Azul_Verde_Vermelho.png'),1)
cv.imshow('OpenCV - Color _ Modified',img)
cv.waitKey(5000)
# By Matrix
print("@Inicio normal")
print(img.item(100,70,0))  # pixel específico
print(img.item(100,70,1))  # pixel específico
print(img.item(100,70,2))  # pixel específico

print(img[100,70])
print("@Fim normal")
print(img.shape[0])
print(img.shape[1])
print(img.shape[2])
for i in range(img.shape[0]): # número de linhas
  for j in range(img.shape[1]): # númeto de colunas
    img[i,j,2] = 0 # modifica
cv.imshow('OpenCV - Color _ Modified',img)
print("@Inicio preto")
print(img.item(100,140,0))
print(img.item(100,140,1))
print(img.item(100,140,2))

print(img[100,140])
print("@Fim preto")
cv.waitKey(5000)

for i in range(img.shape[0]):
  for j in range(img.shape[1]):
    img[i,j,2] = 255
cv.imshow('OpenCV - Color _ Modified',img)
print("@Inicio vermelho")
print(img.item(100,140,0))
print(img.item(100,140,1))
print(img.item(100,140,2))

print(img[100,140])
print("@Fim vermelho")
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exemplo 4

img = cv.imread(os.path.join(originais,'ROI_Conjunto_Bebidas.png'),cv.IMREAD_COLOR)
print(img.shape)
ROI = img[180:230,160:190]
cv.imshow('ROI',ROI)
cv.waitKey(5000)

img[180:230,160:190] = 255
cv.imshow('ROI',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exercício

img = cv.imread(os.path.join(originais,'ROI_Conjunto_Bebidas.png'),cv.IMREAD_COLOR)
regiao = [
  [
    167,
    231
  ],
  [
    321,
    379
  ]
]
ROI = img[regiao[0][0]:regiao[0][1],regiao[1][0]:regiao[1][1]]
cv.imshow('ROI',ROI)
cv.waitKey(5000)

img[regiao[0][0]:regiao[0][1],regiao[1][0]:regiao[1][1]] = 255
cv.imshow('ROI',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exemplo 5

image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'),1)

#split the image into its three channels
(blue_channel, green_channel, red_channel) = cv.split(image)

#display the images
cv.imshow('blue channel',blue_channel)
cv.waitKey(5000)
cv.imshow('green channel',green_channel)
cv.waitKey(5000)
cv.imshow('red channel',red_channel) 
cv.waitKey(5000)
image_merged = cv.merge((blue_channel,green_channel,red_channel))
cv.imshow('merged image',image_merged) 
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exemplo 51

image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'),1)
#split the image into its three channels
blue_channel = image[:,:,0];  #Imagens do canal 0 - blue
green_channel = image[:,:,1];  #Imagens do canal 1 - green
red_channel = image[:,:,2];  #Imagens do canal 2 - red

#display the images
cv.imshow('blue channel',blue_channel)
cv.waitKey(5000)
cv.imshow('green channel',green_channel)
cv.waitKey(5000)
cv.imshow('red channel',red_channel) 
cv.waitKey(5000)
image_merged = cv.merge((blue_channel,green_channel,red_channel))
cv.imshow('merged image',image_merged) 
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exemplo 6

image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'),1)
(canalAzul, canalVerde, canalVermelho) = cv.split(image)

zeros = np.zeros(image.shape[:2], dtype = "uint8")

cv.imshow("Vermelho", cv.merge([zeros, zeros,canalVermelho]))
cv.waitKey(5000)
cv.imshow("Verde", cv.merge([zeros, canalVerde, zeros]))
cv.waitKey(5000)
cv.imshow("Azul", cv.merge([canalAzul, zeros, zeros]))
cv.waitKey(5000)
cv.imshow("Original", cv.merge([canalAzul, canalVerde, canalVermelho]))
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exemplo 61

imageClone1 = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'))
imageClone1[:,:,0] = 0
imageClone1[:,:,1] = 0
cv.imshow("Vermelho", imageClone1)
cv.waitKey(5000)
imageClone2 = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'))
imageClone2[:,:,0] = 0
imageClone2[:,:,2] = 0
cv.imshow("Verde", imageClone2)
cv.waitKey(5000)
imageClone3 = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'))
imageClone3[:,:,1] = 0
imageClone3[:,:,2] = 0
cv.imshow("Azul", imageClone3)
cv.waitKey(5000)
image_merged = cv.merge((imageClone3[:,:,0],imageClone2[:,:,1],imageClone1[:,:,2]))
cv.imshow('merged image',image_merged) 
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exemplo 7

img = cv.imread(os.path.join(originais,'ROI_Conjunto_Bebidas.png'),cv.IMREAD_COLOR) 

image = cv.resize(img, (1280, 720))
 
pt1 = (400, 40)
pt2 = (800, 300)
color = (0, 255, 255)
thickness = 1
lineType = cv.LINE_4

 
img_rect = cv.rectangle(image, pt1, pt2, color, thickness, lineType) 
cv.imshow("Conjunto_Bebidas", img_rect) 
cv.waitKey(2000)

thickness = -1
img_rect = cv.rectangle(image, pt1, pt2, color, thickness, lineType)
cv.imshow("Conjunto_Bebidas", img_rect)
cv.waitKey(3000)

text = "Minhas Bebidas!!!"
onde = (450, 170)
fontFace = cv.FONT_HERSHEY_SIMPLEX
fontScale = 1
color = (0,0,255) 
img_text = cv.putText(img_rect, text, onde, fontFace, fontScale, color, lineType) 
cv.imshow("Conjunto_Bebidas",img_text)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exemplo 71

# Create a black image
img = np.zeros((512,512,3), np.uint8)
# Draw a diagonal blue line with thickness of 5 px
cv.line(img,(0,0),(511,511),(255,0,0),5)

cv.circle(img,(447,63), 63, (0,0,255), -1)

for x in range(63, img.shape[0], 63):
  cv.circle(img,(x,189), 63, (0,255,0), 1)

#Para desenhar um polígono, primeiro precisa-se das coordenadas dos vértices.
#Transforme esses pontos em uma matriz de formato ROWSx1x2 onde ROWS é o número de vértices e deve ser do tipo int32.
#Aqui desenha-se um pequeno polígono com quatro vértices na cor amarela.

pts = np.array([[10,50],[20,80],[70,40],[90,10]], np.int32)
cv.polylines(img,[pts],True,(0,255,255))


font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,'Formas',(10,500), font, 4,(255,255,255),2,cv.LINE_AA)

cv.imshow("Desenhando_Formas",img)
print (img.shape)

cv.waitKey(0)
cv.destroyAllWindows()

# %%
# Exercício 2

image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'))

y,x,canais = image.shape

print(f'Dimensão (y,x,n): {y},{x},{canais}') # y,x,n

cv.line(image,(0,0),(x-1,y-1),(255,0,0),2,cv.LINE_4)
cv.line(image,(x-1,0),(0,y-1),(255,0,0),2,cv.LINE_4)
cv.line(image,(int(x/2),0),(int(x/2),y-1),(255,0,0),2,cv.LINE_4)
#cv.line(image,(0,int(y/2)),(x-1,int(y/2)),(255,0,0),2,cv.LINE_4)
font = cv.FONT_HERSHEY_SIMPLEX 

cv.putText(image,'Boa comida!',(50,int(y/2)),font,2,(255,255,255),2,cv.LINE_AA)

cv.imshow("Exercício 2",image)
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_Refeicao_Chile.jpg"), image)
cv.waitKey(5000)
cv.destroyAllWindows()

# %% [markdown]
# # Aula 3
#
# Enviar arquivo para mariah.silveira@uerj.br

# %%
# Exemplo 8

# Read the image using imread function
image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_RottWeiler.jpg'))
cv.imshow('Original Image', image)
cv.waitKey()
print (image.shape)
 
# let's downscale the image using new  width and height
down_width = 300
down_height = 100
down_points = (down_width, down_height)
resized_down = cv.resize(image, down_points, interpolation= cv.INTER_LINEAR)
 
# let's upscale the image using new  width and height
up_width = 900
up_height = 650
up_points = (up_width, up_height)
resized_up = cv.resize(image, up_points, interpolation= cv.INTER_LINEAR)
 
# Display images
cv.imshow('Resized Down by defining height and width', resized_down)
cv.waitKey()
cv.imshow('Resized Up image by defining height and width', resized_up)
cv.waitKey()
 
#press any key to close the windows
cv.destroyAllWindows()

# %%
#Exemplo 81

image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_RottWeiler.jpg'))
cv.imshow('Original Image', image)
print (image.shape)
cv.waitKey()

# Reduz a imagem 0.5 vez
scale_down = 0.5
scaled_f_down = cv.resize(image, None, fx= scale_down, fy= scale_down, interpolation= cv.INTER_LINEAR)
 
# Aumenta a imagem 1.5 vezes
scale_up_x = 1.5
scale_up_y = 1.5
scaled_f_up = cv.resize(image, None, fx= scale_up_x, fy= scale_up_y, interpolation= cv.INTER_LINEAR)
 
# Apresenta imagens
cv.imshow('Resized Down by defining height and width', scaled_f_down)
cv.waitKey()

#Tecle enter para ver
cv.imshow('Resized Up image by defining height and width', scaled_f_up)
cv.waitKey()
 
#press any key to close the windows
cv.destroyAllWindows()

# %%
#Exemplo 82

# Reading the image
image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_RottWeiler.jpg'))
cv.imshow('Original Image', image)
print (image.shape)
cv.waitKey()

 
# dividing height and width by 2 to get the center of the image
height, width = image.shape[:2]
print(image.shape[:2])
# get the center coordinates of the image to create the 2D rotation matrix
center = (width/2, height/2)
 
# using cv.getRotationMatrix2D() to get the rotation matrix
rotate_matrix = cv.getRotationMatrix2D(center=center, angle=45, scale=1)
 
# rotate the image using cv.warpAffine
rotated_image = cv.warpAffine(src=image, M=rotate_matrix, dsize=(width, height))
 
cv.imshow('Original image', image)
cv.imshow('Rotated image', rotated_image)
# wait indefinitely, press any key on keyboard to exit
cv.waitKey()

#press any key to close the windows
cv.destroyAllWindows()

# %%
#Exercício 3

# Carrega a imagem
image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'))
y,x,c = image.shape
print(f'Imagem original dimensão (y,x,n): ({y},{x},{c})')
cv.imshow('Imagem Original',image)
cv.waitKey()

# Rotação e Redimensionamento
scale = 0.5
angle = 60
center = (int(x/2),int(y/2))
matrix = cv.getRotationMatrix2D(center=center,angle=angle,scale=scale)
rotated_image = cv.warpAffine(src=image,M=matrix,dsize=(int(x*scale),int(y*scale)))
cv.imshow('Imgem Rotacionada e Aumentada',rotated_image)
cv.waitKey()
cv.resizeWindow('Imagem redimensionada',)
cv.imshow('Imgem Redimensionada',rotated_image)
cv.waitKey()
cv.destroyAllWindows()

# %%
#Exemplo 9

# Read image 
src = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_RottWeiler.jpg'),cv.IMREAD_GRAYSCALE); 
cv.imshow('Imagem Original',src)

# Basic threhold example 
th, dst = cv.threshold(src, 0, 255, cv.THRESH_BINARY)
print('THRESH_BINARY')
cv.imwrite(os.path.join(copias,'VisaoComputacional_Imagem_RottWeiler-Threshold-Example.jpg'), dst)
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_RottWeiler-Threshold-Example.jpg'))
cv.imshow('Imagem_RottWeiler-Threshold-Example',image)
cv.waitKey()
print(th)
# Thresholding with maxValue set to 128
th, dst = cv.threshold(src, 0, 128, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_RottWeiler-thresh-binary-maxval.jpg"), dst)
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_RottWeiler-thresh-binary-maxval.jpg'))
cv.imshow('Imagem_RottWeiler-Threshold-Example',image)
cv.waitKey()
 
# Thresholding with threshold value set 127 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_RottWeiler-thresh-binary.jpg"), dst)
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_RottWeiler-thresh-binary.jpg'))
cv.imshow('Imagem_RottWeiler-Threshold-Example',image)
cv.waitKey()
print(th)
# Thresholding using THRESH_BINARY_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY_INV)
print('THRESH_BINARY_INV')
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_RottWeiler-thresh-binary-inv.jpg"), dst); 
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_RottWeiler-thresh-binary-inv.jpg'))
cv.imshow('Imagem_RottWeiler-Threshold-Example',image)
cv.waitKey()

# Thresholding using THRESH_TRUNC 
th, dst = cv.threshold(src,127,255, cv.THRESH_TRUNC)
print('THRESH_TRUNC')
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_RottWeiler-thresh-trunc.jpg"), dst); 
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_RottWeiler-thresh-trunc.jpg'))
cv.imshow('Imagem_RottWeiler-Threshold-Example',image)
cv.waitKey()

# Thresholding using THRESH_TOZERO 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO)
print('THRESH_TOZERO')
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_RottWeiler-thresh-tozero.jpg"), dst); 
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_RottWeiler-thresh-tozero.jpg'))
cv.imshow('Imagem_RottWeiler-Threshold-Example',image)
cv.waitKey()

# Thresholding using THRESH_TOZERO_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO_INV)
print('THRESH_TOZERO_INV')
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_RottWeiler-thresh-to-zero-inv.jpg"), dst)
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_RottWeiler-thresh-to-zero-inv.jpg'))
cv.imshow('Imagem_RottWeiler-Threshold-Example',image)
cv.waitKey()

cv.destroyAllWindows()
# Out:
# THRESH_BINARY
# 0.0
# 127.0
# THRESH_BINARY_INV
# THRESH_TRUNC
# THRESH_TOZERO
# THRESH_TOZERO_INV

# %%
#Exercicio 4

# Refeiçaõ no Chile
# Read image 
src = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'),cv.IMREAD_GRAYSCALE); 
cv.imshow('Refeição no Chile Original',src)
#cv.waitKey()

# Basic threhold example 
th, dst = cv.threshold(src, 0, 255, cv.THRESH_BINARY)
print('THRESH_BINARY')
cv.imwrite(os.path.join(copias,'VisaoComputacional_Imagem_Refeicao_Chile-Threshold-Example.jpg'), dst)
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_Refeicao_Chile-Threshold-Example.jpg'))
cv.imshow('Refeição no Chile Threshold',image)
#cv.waitKey()
print(th)
# Thresholding with maxValue set to 128
th, dst = cv.threshold(src, 0, 128, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_Refeicao_Chile-thresh-binary-maxval.jpg"), dst)
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_Refeicao_Chile-thresh-binary-maxval.jpg'))
cv.imshow('Refeição no Chile Threshold binary maxval',image)
#cv.waitKey()
 
# Thresholding with threshold value set 127 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_Refeicao_Chile-thresh-binary.jpg"), dst)
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_Refeicao_Chile-thresh-binary.jpg'))
cv.imshow('Refeição no Chile Threshold binary',image)
#cv.waitKey()
print(th)
# Thresholding using THRESH_BINARY_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY_INV)
print('THRESH_BINARY_INV')
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_Refeicao_Chile-thresh-binary-inv.jpg"), dst); 
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_Refeicao_Chile-thresh-binary-inv.jpg'))
cv.imshow('Refeição no Chile Threshold binary inv',image)
#cv.waitKey()

# Thresholding using THRESH_TRUNC 
th, dst = cv.threshold(src,127,255, cv.THRESH_TRUNC)
print('THRESH_TRUNC')
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_Refeicao_Chile-thresh-trunc.jpg"), dst); 
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_Refeicao_Chile-thresh-trunc.jpg'))
cv.imshow('Refeição no Chile Threshold trunc',image)
#cv.waitKey()

# Thresholding using THRESH_TOZERO 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO)
print('THRESH_TOZERO')
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_Refeicao_Chile-thresh-tozero.jpg"), dst); 
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_Refeicao_Chile-thresh-tozero.jpg'))
cv.imshow('Refeição no Chile Threshold tozero',image)
#cv.waitKey()

# Thresholding using THRESH_TOZERO_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO_INV)
print('THRESH_TOZERO_INV')
cv.imwrite(os.path.join(copias,"VisaoComputacional_Imagem_Refeicao_Chile-thresh-to-zero-inv.jpg"), dst)
image = cv.imread(os.path.join(copias,'VisaoComputacional_Imagem_Refeicao_Chile-thresh-to-zero-inv.jpg'))
cv.imshow('Refeição no Chile Threshold tozero inv',image)
cv.waitKey()

cv.destroyAllWindows()

# Tigre
# Read image 
src = cv.imread(os.path.join(originais,'Tigre_001.jpg'),cv.IMREAD_GRAYSCALE); 
cv.imshow('Tigre Original',src)
#cv.waitKey()

# Basic threhold example 
th, dst = cv.threshold(src, 0, 255, cv.THRESH_BINARY)
print('THRESH_BINARY')
cv.imwrite(os.path.join(copias,'Tigre_001-Threshold-Example.jpg'), dst)
image = cv.imread(os.path.join(copias,'Tigre_001-Threshold-Example.jpg'))
cv.imshow('Tigre Threshold',image)
#cv.waitKey()
print(th)
# Thresholding with maxValue set to 128
th, dst = cv.threshold(src, 0, 128, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"Tigre_001-thresh-binary-maxval.jpg"), dst)
image = cv.imread(os.path.join(copias,'Tigre_001-thresh-binary-maxval.jpg'))
cv.imshow('Tigre Threshold binary maxval',image)
#cv.waitKey()
 
# Thresholding with threshold value set 127 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"Tigre_001-thresh-binary.jpg"), dst)
image = cv.imread(os.path.join(copias,'Tigre_001-thresh-binary.jpg'))
cv.imshow('Tigre Threshold binary',image)
#cv.waitKey()
print(th)
# Thresholding using THRESH_BINARY_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY_INV)
print('THRESH_BINARY_INV')
cv.imwrite(os.path.join(copias,"Tigre_001-thresh-binary-inv.jpg"), dst); 
image = cv.imread(os.path.join(copias,'Tigre_001-thresh-binary-inv.jpg'))
cv.imshow('Tigre Threshold binary inv',image)
#cv.waitKey()

# Thresholding using THRESH_TRUNC 
th, dst = cv.threshold(src,127,255, cv.THRESH_TRUNC)
print('THRESH_TRUNC')
cv.imwrite(os.path.join(copias,"Tigre_001-thresh-trunc.jpg"), dst); 
image = cv.imread(os.path.join(copias,'Tigre_001-thresh-trunc.jpg'))
cv.imshow('Tigre Threshold trunc',image)
#cv.waitKey()

# Thresholding using THRESH_TOZERO 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO)
print('THRESH_TOZERO')
cv.imwrite(os.path.join(copias,"Tigre_001-thresh-tozero.jpg"), dst); 
image = cv.imread(os.path.join(copias,'Tigre_001-thresh-tozero.jpg'))
cv.imshow('Tigre Threshold tozero',image)
#cv.waitKey()

# Thresholding using THRESH_TOZERO_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO_INV)
print('THRESH_TOZERO_INV')
cv.imwrite(os.path.join(copias,"Tigre_001-thresh-to-zero-inv.jpg"), dst)
image = cv.imread(os.path.join(copias,'Tigre_001-thresh-to-zero-inv.jpg'))
cv.imshow('Tigre Threshold tozero inv',image)
cv.waitKey()

cv.destroyAllWindows()


# Bebida
# Read image 
src = cv.imread(os.path.join(originais,'ROI_Conjunto_Bebidas.png'),cv.IMREAD_GRAYSCALE); 
cv.imshow('Bebidas Original',src)
#cv.waitKey()

# Basic threhold example 
th, dst = cv.threshold(src, 0, 255, cv.THRESH_BINARY)
print('THRESH_BINARY')
cv.imwrite(os.path.join(copias,'ROI_Conjunto_Bebidas-Threshold-Example.png'), dst)
image = cv.imread(os.path.join(copias,'ROI_Conjunto_Bebidas-Threshold-Example.png'))
cv.imshow('Bebidas Threshold',image)
#cv.waitKey()
print(th)
# Thresholding with maxValue set to 128
th, dst = cv.threshold(src, 0, 128, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"ROI_Conjunto_Bebidas-thresh-binary-maxval.png"), dst)
image = cv.imread(os.path.join(copias,'ROI_Conjunto_Bebidas-thresh-binary-maxval.png'))
cv.imshow('Bebidas Threshold binary maxval',image)
#cv.waitKey()
 
# Thresholding with threshold value set 127 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"ROI_Conjunto_Bebidas-thresh-binary.png"), dst)
image = cv.imread(os.path.join(copias,'ROI_Conjunto_Bebidas-thresh-binary.png'))
cv.imshow('Bebidas Threshold binary',image)
#cv.waitKey()
print(th)
# Thresholding using THRESH_BINARY_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY_INV)
print('THRESH_BINARY_INV')
cv.imwrite(os.path.join(copias,"ROI_Conjunto_Bebidas-thresh-binary-inv.png"), dst); 
image = cv.imread(os.path.join(copias,'ROI_Conjunto_Bebidas-thresh-binary-inv.png'))
cv.imshow('Bebidas Threshold binary inv',image)
#cv.waitKey()

# Thresholding using THRESH_TRUNC 
th, dst = cv.threshold(src,127,255, cv.THRESH_TRUNC)
print('THRESH_TRUNC')
cv.imwrite(os.path.join(copias,"ROI_Conjunto_Bebidas-thresh-trunc.png"), dst); 
image = cv.imread(os.path.join(copias,'ROI_Conjunto_Bebidas-thresh-trunc.png'))
cv.imshow('Bebidas Threshold trunc',image)
#cv.waitKey()

# Thresholding using THRESH_TOZERO 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO)
print('THRESH_TOZERO')
cv.imwrite(os.path.join(copias,"ROI_Conjunto_Bebidas-thresh-tozero.png"), dst); 
image = cv.imread(os.path.join(copias,'ROI_Conjunto_Bebidas-thresh-tozero.png'))
cv.imshow('Bebidas Threshold tozero',image)
#cv.waitKey()

# Thresholding using THRESH_TOZERO_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO_INV)
print('THRESH_TOZERO_INV')
cv.imwrite(os.path.join(copias,"ROI_Conjunto_Bebidas-thresh-to-zero-inv.png"), dst)
image = cv.imread(os.path.join(copias,'ROI_Conjunto_Bebidas-thresh-to-zero-inv.png'))
cv.imshow('Bebidas Threshold tozero inv',image)
cv.waitKey()

cv.destroyAllWindows()

# Menina
# Read image 
src = cv.imread(os.path.join(originais,'Rosto_de_Menina_001.png'),cv.IMREAD_GRAYSCALE); 
cv.imshow('Menina Original',src)
#cv.waitKey()

# Basic threhold example 
th, dst = cv.threshold(src, 0, 255, cv.THRESH_BINARY)
print('THRESH_BINARY')
cv.imwrite(os.path.join(copias,'Rosto_de_Menina_001-Threshold-Example.png'), dst)
image = cv.imread(os.path.join(copias,'Rosto_de_Menina_001-Threshold-Example.png'))
cv.imshow('Menina Threshold',image)
#cv.waitKey()
print(th)
# Thresholding with maxValue set to 128
th, dst = cv.threshold(src, 0, 128, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"Rosto_de_Menina_001-thresh-binary-maxval.png"), dst)
image = cv.imread(os.path.join(copias,'Rosto_de_Menina_001-thresh-binary-maxval.png'))
cv.imshow('Menina Threshold binary maxval',image)
#cv.waitKey()
 
# Thresholding with threshold value set 127 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY)
cv.imwrite(os.path.join(copias,"Rosto_de_Menina_001-thresh-binary.png"), dst)
image = cv.imread(os.path.join(copias,'Rosto_de_Menina_001-thresh-binary.png'))
cv.imshow('Menina Threshold binary',image)
#cv.waitKey()
print(th)
# Thresholding using THRESH_BINARY_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_BINARY_INV)
print('THRESH_BINARY_INV')
cv.imwrite(os.path.join(copias,"Rosto_de_Menina_001-thresh-binary-inv.png"), dst); 
image = cv.imread(os.path.join(copias,'Rosto_de_Menina_001-thresh-binary-inv.png'))
cv.imshow('Menina Threshold binary inv',image)
#cv.waitKey()

# Thresholding using THRESH_TRUNC 
th, dst = cv.threshold(src,127,255, cv.THRESH_TRUNC)
print('THRESH_TRUNC')
cv.imwrite(os.path.join(copias,"Rosto_de_Menina_001-thresh-trunc.png"), dst); 
image = cv.imread(os.path.join(copias,'Rosto_de_Menina_001-thresh-trunc.png'))
cv.imshow('Menina Threshold trunc',image)
#cv.waitKey()

# Thresholding using THRESH_TOZERO 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO)
print('THRESH_TOZERO')
cv.imwrite(os.path.join(copias,"Rosto_de_Menina_001-thresh-tozero.png"), dst); 
image = cv.imread(os.path.join(copias,'Rosto_de_Menina_001-thresh-tozero.png'))
cv.imshow('Menina Threshold tozero',image)
#cv.waitKey()

# Thresholding using THRESH_TOZERO_INV 
th, dst = cv.threshold(src,127,255, cv.THRESH_TOZERO_INV)
print('THRESH_TOZERO_INV')
cv.imwrite(os.path.join(copias,"Rosto_de_Menina_001-thresh-to-zero-inv.png"), dst)
image = cv.imread(os.path.join(copias,'Rosto_de_Menina_001-thresh-to-zero-inv.png'))
cv.imshow('Menina Threshold tozero inv',image)
cv.waitKey()

cv.destroyAllWindows()
# Out:
# THRESH_BINARY
# 0.0
# 127.0
# THRESH_BINARY_INV
# THRESH_TRUNC
# THRESH_TOZERO
# THRESH_TOZERO_INV
# THRESH_BINARY
# 0.0
# 127.0
# THRESH_BINARY_INV
# THRESH_TRUNC
# THRESH_TOZERO
# THRESH_TOZERO_INV
# THRESH_BINARY
# 0.0
# 127.0
# THRESH_BINARY_INV
# THRESH_TRUNC
# THRESH_TOZERO
# THRESH_TOZERO_INV
# THRESH_BINARY
# 0.0
# 127.0
# THRESH_BINARY_INV
# THRESH_TRUNC
# THRESH_TOZERO
# THRESH_TOZERO_INV

# %%
#Exemplo 91

imagem = cv.imread(os.path.join(originais,'Varios_Madeira_001.jpg'))

cv.imshow('Original', imagem)
cv.waitKey(0)

kernel2 = np.ones((5, 5), np.float32) / 25
imagem2D = cv.filter2D(src=imagem, ddepth=-1, kernel=kernel2)
cv.imshow('filter2D', imagem2D)
cv.waitKey(0)


imagem_blur = cv.blur(src=imagem, ksize=(5,5)) 
cv.imshow('Blurred', imagem_blur) 
cv.waitKey(0)

gaussian_blur = cv.GaussianBlur(src=imagem,ksize=(5,5),sigmaX=0, sigmaY=0)
 

cv.imshow('Gaussian Blurred', gaussian_blur)     
cv.waitKey(0)

median = cv.medianBlur(src=imagem, ksize=5)
cv.imshow('Median Blurred', median)     
cv.waitKey(0)

bilateral_filter = cv.bilateralFilter(src=imagem, d=9, sigmaColor=75, sigmaSpace=75)
cv.imshow('Bilateral Filtering', bilateral_filter) 
cv.waitKey(0)

cv.destroyAllWindows()

# %%
#Exercicio 5

#Refeição no Chile
imagem = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg'))

cv.imshow('Refeição no Chile Original', imagem)
#cv.waitKey(0)

kernel2 = np.ones((5, 5), np.float32) / 25
imagem2D = cv.filter2D(src=imagem, ddepth=-1, kernel=kernel2)
cv.imshow('Refeição no Chile filter2D', imagem2D)
#cv.waitKey(0)

imagem_blur = cv.blur(src=imagem, ksize=(5,5)) 
cv.imshow('Refeição no Chile Blurred', imagem_blur) 
#cv.waitKey(0)

gaussian_blur = cv.GaussianBlur(src=imagem,ksize=(5,5),sigmaX=0, sigmaY=0)

cv.imshow('Refeição no Chile Gaussian Blurred', gaussian_blur)     
#cv.waitKey(0)

median = cv.medianBlur(src=imagem, ksize=5)
cv.imshow('Refeição no Chile Median Blurred', median)     
#cv.waitKey(0)

bilateral_filter = cv.bilateralFilter(src=imagem, d=9, sigmaColor=75, sigmaSpace=75)
cv.imshow('Refeição no Chile Bilateral Filtering', bilateral_filter) 
cv.waitKey(0)

cv.destroyAllWindows()

#Tigre
imagem = cv.imread(os.path.join(originais,'Rosto_de_Menina_001.png'))

cv.imshow('Menina Original', imagem)
#cv.waitKey(0)

kernel2 = np.ones((5, 5), np.float32) / 25
imagem2D = cv.filter2D(src=imagem, ddepth=-1, kernel=kernel2)
cv.imshow('Menina filter2D', imagem2D)
#cv.waitKey(0)

imagem_blur = cv.blur(src=imagem, ksize=(5,5)) 
cv.imshow('Menina Blurred', imagem_blur) 
#cv.waitKey(0)

gaussian_blur = cv.GaussianBlur(src=imagem,ksize=(5,5),sigmaX=0, sigmaY=0)
 
cv.imshow('Menina Gaussian Blurred', gaussian_blur)     
#cv.waitKey(0)

median = cv.medianBlur(src=imagem, ksize=5)
cv.imshow('Menina Median Blurred', median)     
#cv.waitKey(0)

bilateral_filter = cv.bilateralFilter(src=imagem, d=9, sigmaColor=75, sigmaSpace=75)
cv.imshow('Menina Bilateral Filtering', bilateral_filter) 
cv.waitKey(0)

cv.destroyAllWindows()

#Tigre
imagem = cv.imread(os.path.join(originais,'Tigre_001.jpg'))

cv.imshow('Tigre Original', imagem)
#cv.waitKey(0)

kernel2 = np.ones((5, 5), np.float32) / 25
imagem2D = cv.filter2D(src=imagem, ddepth=-1, kernel=kernel2)
cv.imshow('Tigre filter2D', imagem2D)
#cv.waitKey(0)

imagem_blur = cv.blur(src=imagem, ksize=(5,5)) 
cv.imshow('Tigre Blurred', imagem_blur) 
#cv.waitKey(0)

gaussian_blur = cv.GaussianBlur(src=imagem,ksize=(5,5),sigmaX=0, sigmaY=0)
 
cv.imshow('Tigre Gaussian Blurred', gaussian_blur)     
#cv.waitKey(0)

median = cv.medianBlur(src=imagem, ksize=5)
cv.imshow('Tigre Median Blurred', median)     
#cv.waitKey(0)

bilateral_filter = cv.bilateralFilter(src=imagem, d=9, sigmaColor=75, sigmaSpace=75)
cv.imshow('Tigre Bilateral Filtering', bilateral_filter) 
cv.waitKey(0)

cv.destroyAllWindows()

#Rottweiler
imagem = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Rottweiler.jpg'))

cv.imshow('Rottweiler Original', imagem)
#cv.waitKey(0)

kernel2 = np.ones((5, 5), np.float32) / 25
imagem2D = cv.filter2D(src=imagem, ddepth=-1, kernel=kernel2)
cv.imshow('Rottweiler filter2D', imagem2D)
#cv.waitKey(0)

imagem_blur = cv.blur(src=imagem, ksize=(5,5)) 
cv.imshow('Rottweiler Blurred', imagem_blur) 
#cv.waitKey(0)

gaussian_blur = cv.GaussianBlur(src=imagem,ksize=(5,5),sigmaX=0, sigmaY=0)
 
cv.imshow('Rottweiler Gaussian Blurred', gaussian_blur)     
#cv.waitKey(0)

median = cv.medianBlur(src=imagem, ksize=5)
cv.imshow('Rottweiler Median Blurred', median)     
#cv.waitKey(0)

bilateral_filter = cv.bilateralFilter(src=imagem, d=9, sigmaColor=75, sigmaSpace=75)
cv.imshow('Rottweiler Bilateral Filtering', bilateral_filter) 
cv.waitKey(0)

cv.destroyAllWindows()

# %%
# Exemplo 10
image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_RottWeiler.jpg'))

image_blur = cv.GaussianBlur(image,(3,3),0) 
edges = cv.Canny(image_blur,100,200)

cv.imshow('Original image', image)
#cv.waitKey()
cv.imshow('Canny image', edges)
inverterd = cv.bitwise_not(image)
cv.imshow('Invertida image', inverterd)

cv.waitKey()

cv.destroyAllWindows()

# %%
#Exemplo 101

# Read the original image
image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_RottWeiler.jpg') )
# Display original image
cv.imshow('Rottweiler Original', image)
#cv.waitKey()
 
# Convert to graycsale
img_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
# Blur the image for better edge detection
img_blur = cv.GaussianBlur(img_gray, (3,3), 0) 

#cv.waitKey()
# Sobel Edge Detection
sobelx = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
# Display Sobel Edge Detection Images
cv.imshow('Rottweiler Sobel X', sobelx)
#cv.waitKey()
cv.imshow('RottweilerSobel Y', sobely)
#cv.waitKey()
cv.imshow('Rottweiler Sobel X Y using Sobel() function', sobelxy)
#cv.waitKey()
 
# Canny Edge Detection
edges = cv.Canny(image=img_blur, threshold1=100, threshold2=200) # Canny Edge Detection
# Display Canny Edge Detection Image
cv.imshow('Rottweiler Canny Edge Detection', edges)
cv.waitKey()
 
cv.destroyAllWindows()

# %%
#Exercício 6

#Refeição no Chile
# Read the original image
image = cv.imread(os.path.join(originais,'VisaoComputacional_Imagem_Refeicao_Chile.jpg') )
# Display original image
cv.imshow('Refeição no Chile Original', image)
#cv.waitKey()
 
# Convert to graycsale
img_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
# Blur the image for better edge detection
img_blur = cv.GaussianBlur(img_gray, (3,3), 0) 

#cv.waitKey()
# Sobel Edge Detection
sobelx = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
# Display Sobel Edge Detection Images
cv.imshow('Refeição no Chile Sobel X', sobelx)
#cv.waitKey()
cv.imshow('Refeição no Chile Sobel Y', sobely)
#cv.waitKey()
cv.imshow('Refeição no Chile Sobel X Y using Sobel() function', sobelxy)
#cv.waitKey()
 
# Canny Edge Detection
edges = cv.Canny(image=img_blur, threshold1=100, threshold2=200) # Canny Edge Detection
# Display Canny Edge Detection Image
cv.imshow('Refeição no Chile Canny Edge Detection', edges)
cv.waitKey()
 
cv.destroyAllWindows()

#Tigre
# Read the original image
image = cv.imread(os.path.join(originais,'Tigre_001.jpg') )
# Display original image
cv.imshow('Tigre Original', image)
#cv.waitKey()
 
# Convert to graycsale
img_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
# Blur the image for better edge detection
img_blur = cv.GaussianBlur(img_gray, (3,3), 0) 

#cv.waitKey()
# Sobel Edge Detection
sobelx = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
# Display Sobel Edge Detection Images
cv.imshow('Tigre Sobel X', sobelx)
#cv.waitKey()
cv.imshow('Tigre Sobel Y', sobely)
#cv.waitKey()
cv.imshow('Tigre Sobel X Y using Sobel() function', sobelxy)
#cv.waitKey()
 
# Canny Edge Detection
edges = cv.Canny(image=img_blur, threshold1=100, threshold2=200) # Canny Edge Detection
# Display Canny Edge Detection Image
cv.imshow('Tigre Canny Edge Detection', edges)
cv.waitKey()
 
cv.destroyAllWindows()

#Bebidas
# Read the original image
image = cv.imread(os.path.join(originais,'ROI_Conjunto_Bebidas.png') )
# Display original image
cv.imshow('Bebidas Original', image)
#cv.waitKey()
 
# Convert to graycsale
img_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
# Blur the image for better edge detection
img_blur = cv.GaussianBlur(img_gray, (3,3), 0) 

#cv.waitKey()
# Sobel Edge Detection
sobelx = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
# Display Sobel Edge Detection Images
cv.imshow('Bebidas Sobel X', sobelx)
#cv.waitKey()
cv.imshow('Bebidas Sobel Y', sobely)
#cv.waitKey()
cv.imshow('Bebidas Sobel X Y using Sobel() function', sobelxy)
#cv.waitKey()
 
# Canny Edge Detection
edges = cv.Canny(image=img_blur, threshold1=100, threshold2=200) # Canny Edge Detection
# Display Canny Edge Detection Image
cv.imshow('Bebidas Canny Edge Detection', edges)
cv.waitKey()
 
cv.destroyAllWindows()

#Menina
# Read the original image
image = cv.imread(os.path.join(originais,'Rosto_de_Menina_001.png') )
# Display original image
cv.imshow('Menina Original', image)
#cv.waitKey()
 
# Convert to graycsale
img_gray = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
# Blur the image for better edge detection
img_blur = cv.GaussianBlur(img_gray, (3,3), 0) 

#cv.waitKey()
# Sobel Edge Detection
sobelx = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv.Sobel(src=img_blur, ddepth=cv.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
# Display Sobel Edge Detection Images
cv.imshow('Menina Sobel X', sobelx)
#cv.waitKey()
cv.imshow('Menina Sobel Y', sobely)
#cv.waitKey()
cv.imshow('Menina Sobel X Y using Sobel() function', sobelxy)
#cv.waitKey()
 
# Canny Edge Detection
edges = cv.Canny(image=img_blur, threshold1=100, threshold2=200) # Canny Edge Detection
# Display Canny Edge Detection Image
cv.imshow('Menina Canny Edge Detection', edges)
cv.waitKey()
 
cv.destroyAllWindows()

# %% [markdown]
# # Aula 4
